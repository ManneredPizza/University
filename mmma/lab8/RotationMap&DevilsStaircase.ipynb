# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
import matplotlib as mpl

# %%
def f(theta, Omega, epsilon):
    return (theta+Omega+np.dot(epsilon,np.sin(theta)))%(2*math.pi)
def F(theta, Omega, epsilon, N):
    if N==1:
        return theta+Omega+np.dot(epsilon,np.sin(theta))
    else:
        return F(theta+Omega+np.dot(epsilon,np.sin(theta)), Omega, epsilon, N-1)

# %%
Om = np.linspace(0,1,100)
th = np.linspace(0,1,100)

# %%
plt.scatter(th,f(np.dot(2*math.pi,th),0.1*2*math.pi,0)/(2*math.pi),1.2)
#plt.xlabel(r'$\mathrm{theta}$')
#plt.ylabel(r'$\mathrm{f(\mathrm{theta})}$')
plt.show()

# %%
#w = lim n->+inf (F^n(th)-th)/n
N=1000
t = 2*math.pi*0.8
eps = 0
plt.scatter(Om,(F(t,np.dot(Om,2*math.pi),eps,N)-t)/(2*math.pi*N),1.2)
#plt.xlabel(r'$\Omega$')
#plt.ylabel(r'$\omega$')
plt.show()

# %%
plt.scatter(th,f(np.dot(2*math.pi,th),0.1*2*math.pi,3.5)/(2*math.pi),1.2)
#plt.xlabel(r'$\theta$')
#plt.ylabel(r'$f(\theta)$')
plt.show()

# %%
#w = lim n->+inf (F^n(th)-th)/n
N=1000
t = 2*math.pi*0.2
eps = 3.5
plt.scatter(Om,(F(t,np.dot(Om,2*math.pi),eps,N)-t)/(2*math.pi*N),.5)
#plt.xlabel(r'$\Omega$')
#plt.ylabel(r'$\omega$')
plt.show()

# %%
#fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(8,8))
t = 2*math.pi*0.2


epsy = np.linspace(0,5,100)
Omx = np.dot(Om,2*math.pi)

omega = np.ones((100,100))

for i in range(100):
    for j in range(100):
        omega[j,i] *= (F(t, Omx[i], epsy[j], N)-t)/(2*math.pi*N)
        
Omx = np.dot(1/(2*math.pi), Omx)
Omx, epsy = np.meshgrid(Omx, epsy)

#ax.set_xlabel(r'$\Omega$')
#ax.set_ylabel(r'$\epsilon$')
#ax.set_zlabel(r'$\omega$')
lev = np.linspace(omega.min(), omega.max(), 100)

plt.contourf(Omx, epsy, omega, levels = lev)
plt.colorbar()
plt.show()
