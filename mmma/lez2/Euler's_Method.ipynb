# %%
import math
import matplotlib.pyplot as plt

# %%
h = 1/100
w = 2
N = 1000
p = [0.2]
q = [0.3]

# %%
for i in range(N):
    q.append(q[i]+h*p[i])
    p.append(p[i]+h*((-w**2)*q[i-1]))

# %%
p
# Out:
# [0.2,
#  0.188,
#  0.17592,
#  0.1637648,
#  0.151539232,
#  0.13924815808,
#  0.12689646846719999,
#  0.11448907959116798,
#  0.10203093212774911,
#  0.08952698903249376,
#  0.18792,
#  0.176,
#  0.16383999999999999]

# %%
q
# Out:
# [0.3,
#  0.302,
#  0.30388,
#  0.3056392,
#  0.307276848,
#  0.30879224031999997,
#  0.3101847219008,
#  0.311453686585472,
#  0.3125985773813837,
#  0.3136188867026612,
#  0.302,
#  0.30388,
#  0.3056392]

# %%
plt.plot(p,q)
